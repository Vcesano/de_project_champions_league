-- %%
INSERT INTO proyecto_champions_league.gold.fact_posiciones_gold(
    id,
    temporada,
    grupo,
    posicion,
    equipo_id,
    jugados,
    ganados,
    empatados,
    perdidos,
    goles_favor,
    goles_contra,
    diferencia,
    puntos
)
SELECT
    id,
    temporada,
    grupo,
    posicion,
    equipo_id,
    jugados,
    ganados,
    empatados,
    perdidos,
    goles_favor,
    goles_contra,
    diferencia,
    puntos
FROM proyecto_champions_league.silver.posiciones_silver
ORDER BY
    temporada DESC,
    posicion ASC
