-- %%
INSERT INTO proyecto_champions_league.gold.fact_goleadores_gold(id, temporada, jugador_id, equipo_id, goles, asistencias, penales)
SELECT
    id,
    temporada,
    jugador_id,
    equipo_id,
    goles,
    asistencias,
    penales
FROM proyecto_champions_league.silver.goleadores_silver
ORDER BY
    temporada DESC,
    goles DESC,
    asistencias DESC,
    penales DESC
