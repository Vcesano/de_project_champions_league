# %%
# %sql
INSERT INTO proyecto_champions_league.gold.dim_jugadores_gold(id, nombre, pais, posicion)
SELECT DISTINCT
    jugador_id  id,
    jugador_nombre nombre,
    jugador_pais pais,
    jugador_posicion posicion
FROM proyecto_champions_league.silver.goleadores_silver
