-- %%
DROP TABLE IF EXISTS proyecto_champions_league.silver.goleadores_silver;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.silver.goleadores_silver (
    id STRING NOT NULL,
    temporada INT NOT NULL,
    jugador_id INT NOT NULL,
    jugador_nombre STRING,
    jugador_pais STRING,
    latitud_pais DECIMAL(10,5),
    longitud_pais DECIMAL(10,5),
    jugador_posicion STRING,
    equipo_id INT,
    goles INT,
    asistencias INT,
    penales INT,
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
    _source_table STRING DEFAULT 'proyecto_champions_league.bronze.goleadores_bronze'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla de goleadores - SILVER'
