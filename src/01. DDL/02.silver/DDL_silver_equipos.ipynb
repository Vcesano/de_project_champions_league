-- %%
DROP TABLE IF EXISTS proyecto_champions_league.silver.equipos_silver;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.silver.equipos_silver (
    id INT NOT NULL,
    nombre STRING,
    sigla STRING,
    codigo_pais STRING,
    pais STRING,
    latitud_pais DECIMAL(10,5),
    longitud_pais DECIMAL(10,5),
    estadio STRING, 
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
    _source_table STRING DEFAULT 'proyecto_champions_league.bronze.equipos_bronze'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla de equipos - SILVER'
