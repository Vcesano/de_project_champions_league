-- %%
DROP TABLE IF EXISTS  proyecto_champions_league.gold.dim_equipos_gold;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.gold.dim_equipos_gold (
    id INT NOT NULL,
    nombre STRING,
    pais STRING,
    latitud_pais DECIMAL(10,5),
    longitud_pais DECIMAL(10,5),
    estadio STRING,
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
    _source_table STRING DEFAULT 'proyecto_champions_league.silver.equipos_silver'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla dimensional de Equipos - GOLD'
