-- %%
DROP TABLE IF EXISTS proyecto_champions_league.bronze.partidos_bronze;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.bronze.partidos_bronze (
    match_id STRING,
    temporada STRING,
    fecha_utc STRING,
    status STRING,
    stage STRING,
    grupo STRING,
    jornada STRING,
    local_id STRING,
    local_nombre STRING,
    local_sigla STRING,
    visitante_id STRING,
    visitante_nombre STRING,
    visitante_sigla STRING,
    goles_local STRING,
    goles_visitante STRING,
    goles_local_ht STRING,
    goles_visitante_ht STRING,
    goles_local_et STRING,
    goles_visitante_et STRING,
    goles_local_pen STRING,
    goles_visitante_pen STRING,
    ganador STRING,
    arbitro STRING,
    arbitro_pais STRING,
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp() COMMENT 'Timestamp de procesamiento'
)
USING DELTA
TBLPROPERTIES('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla de partidos y resultados - BRONZE'
