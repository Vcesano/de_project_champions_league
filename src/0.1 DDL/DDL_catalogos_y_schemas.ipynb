-- %%
CREATE CATALOG IF NOT EXISTS proyecto_champions_league;

-- %%
CREATE SCHEMA IF NOT EXISTS proyecto_champions_league.bronze;
CREATE SCHEMA IF NOT EXISTS proyecto_champions_league.silver;
CREATE SCHEMA IF NOT EXISTS proyecto_champions_league.gold;
CREATE SCHEMA IF NOT EXISTS proyecto_champions_league.semantica;
