-- %%
DROP TABLE IF EXISTS  proyecto_champions_league.silver.posiciones_silver;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.silver.posiciones_silver (
    id STRING NOT NULL,
    temporada INT NOT NULL,
    grupo STRING,
    posicion INT NOT NULL,
    equipo_id INT NOT NULL,
    jugados INT,
    ganados INT, 
    empatados INT,
    perdidos INT,
    goles_favor INT,
    goles_contra INT,
    diferencia INT,
    puntos INT,
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
    _source_table STRING DEFAULT 'proyecto_champions_league.bronze.posiciones_bronze'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla de posiciones - SILVER'
