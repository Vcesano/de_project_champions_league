-- %%
DROP TABLE IF EXISTS proyecto_champions_league.silver.partidos_silver;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.silver.partidos_silver (
    id INT NOT NULL,
    temporada INT,
    fecha DATE,
    fase STRING,
    grupo STRING,
    jornada INT,
    local_id INT,
    visitante_id INT,
    goles_local INT,
    goles_visitante INT,
    goles_local_ht INT,
    goles_visitante_ht INT,
    goles_local_et INT,
    goles_visitante_et INT,
    goles_local_pen INT,
    goles_visitante_pen INT,
    ganador STRING,
    arbitro  STRING,
    arbitro_pais STRING, 
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
    _source_table STRING DEFAULT 'proyecto_champions_league.bronze.partidos_bronze'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla de partidos y resultados - SILVER'
