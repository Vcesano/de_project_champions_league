-- %%
DROP TABLE IF EXISTS  proyecto_champions_league.gold.dim_jugadores_gold;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.gold.dim_jugadores_gold (
    id INT NOT NULL,
    nombre STRING,
    pais STRING,
    posicion STRING,
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
    _source_table STRING DEFAULT 'proyecto_champions_league.silver.goleadores_silver'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla dimensional de Jugadores - GOLD'
