-- %%
DROP TABLE IF EXISTS  proyecto_champions_league.gold.fact_posiciones_gold;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.gold.fact_posiciones_gold (
  id                    STRING       NOT NULL,
  temporada             INT,
  grupo                 STRING,
  posicion              INT,
  equipo_id             INT,
  jugados               INT,
  ganados               INT,
  empatados             INT,
  perdidos              INT,
  goles_favor           INT,
  goles_contra          INT,
  diferencia            INT,
  puntos                INT,
  _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
  _source_table         STRING DEFAULT 'proyecto_champions_league.silver.posiciones_silver'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla de hechos de Posiciones - GOLD'
