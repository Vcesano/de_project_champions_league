-- %%
DROP TABLE IF EXISTS  proyecto_champions_league.gold.fact_goleadores_gold;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.gold.fact_goleadores_gold (
    id STRING NOT NULL,
    temporada INT,
    jugador_id INT,
    equipo_id INT,
    goles INT,
    asistencias INT,
    penales INT,
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
    _source_table STRING DEFAULT 'proyecto_champions_league.silver.goleadores_silver'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla de hechos de Goleadores - GOLD'
