-- %%
DROP TABLE IF EXISTS  proyecto_champions_league.gold.dim_arbitros_gold;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.gold.dim_arbitros_gold (
    id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
    arbitro STRING,
    arbitro_pais STRING,
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
    _source_table STRING DEFAULT 'proyecto_champions_league.silver.partidos_silver'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla dimensional de arbitros - GOLD'
