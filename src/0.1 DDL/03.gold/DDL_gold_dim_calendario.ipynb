-- %%
DROP TABLE IF EXISTS  proyecto_champions_league.gold.dim_calendario_gold;
CREATE TABLE IF NOT EXISTS proyecto_champions_league.gold.dim_calendario_gold (
    id BIGINT NOT NULL,
    fecha DATE,
    anio INT,
    anio_mes STRING,
    anio_mes_num INT, 
    mes STRING,
    mes_num INT,
    trimestre INT,
    dia_semana STRING,
    dia_semana_num INT,
    es_fin_de_semana BOOLEAN,
    _processing_timestamp TIMESTAMP DEFAULT current_timestamp(),
    _source_table STRING DEFAULT Null
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla dimensional de Fechas - GOLD'
